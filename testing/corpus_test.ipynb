# %%
from convokit import Corpus, download
import os.path

corpus = Corpus(filename = os.path.join(os.path.expanduser("~"), ".convokit/saved-corpora/new-2019"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from convokit import Corpus, download
#       2 import os.path
# ----> 4 corpus = Corpus(filename = os.path.join(os.path.expanduser("~"), ".convokit/saved-corpora/new_corpus_2019"))
#
# File /opt/miniconda3/envs/RA2024/lib/python3.11/site-packages/convokit/model/corpus.py:172, in Corpus.__init__(self, filename, utterances, db_collection_prefix, db_host, preload_vectors, utterance_start_index, utterance_end_index, merge_lines, exclude_utterance_meta, exclude_conversation_meta, exclude_speaker_meta, exclude_overall_meta, disable_type_check, backend, backend_mapper)
#     170     speakers_data = defaultdict(dict)
#     171     convos_data = defaultdict(dict)
# --> 172     utterances = load_from_utterance_file(
#     173         filename, utterance_start_index, utterance_end_index
#     174     )
# ...

# %%
corpus.get_speakers_dataframe()
# Out:
#                      vectors             meta.name meta.type
# id
# j__john_g_roberts_jr      []  John G. Roberts, Jr.         J
# shay_dvoretzky            []        Shay Dvoretzky         A
# j__clarence_thomas        []       Clarence Thomas         J
# j__elena_kagan            []           Elena Kagan         J
# j__amy_coney_barrett      []     Amy Coney Barrett         J
# ...                      ...                   ...       ...
# jean-claude_andre         []     Jean-Claude Andre         A
# theane_d_evangelis        []   Theane D. Evangelis         A
# e_joshua_rosenkranz       []  E. Joshua Rosenkranz         A
# eric_t_lee                []           Eric T. Lee         A
# henry_c_whitaker          []     Henry C. Whitaker         A
#
# [105 rows x 3 columns]

# %%
corpus.get_conversations_dataframe()
# Out:
#       vectors meta.id  meta.case_id  \
# id
# 25478      []   25478   2023_22-340
# 25479      []   25479   2023_22-448
# 25480      []   25480   2023_22-429
# 25482      []   25482   2023_22-660
# 25481      []   25481   2023_22-500
# 25483      []   25483   2023_22-807
# 25485      []   25485   2023_22-585
# 25487      []   25487   2023_22-611
# 25486      []   25486   2023_22-324
# 25495      []   25495   2023_22-704
# 25490      []   25490   2023_22-846
# 25493      []   25493   2023_22-915
# 25496      []   25496   2023_22-888
# 25503      []   25503   2023_22-193
# 25560      []   25560   2023_22-451
# 25561      []   25561  2023_22-1219
# 25499      []   25499   2023_22-666
# 25556      []   25556   2023_22-674
# 25498      []   25498   2023_22-721
# 25502      []   25502   2023_22-800
# 25497      []   25497  2023_22-6389
# 25501      []   25501   2023_23-124
# 25555      []   25555  2023_22-1178
# 25553      []   25553  2023_22-1074
# 25554      []   25554  2023_22-1238
# ...

# %%
corpus.get_utterances_dataframe()
# Out:
#                timestamp                                               text  \
# id
# 25478__1_001        0.17  We will hear argument this morning in Case 22-...
# 25478__1_002  7.42000005  Mr. Chief Justice, and may it please the Court...
# 25478__1_003     131.845  From your argument, it appears you do not acce...
# 25478__1_004     143.325  Not in this context, Justice Thomas, not -- no...
# 25478__1_005      152.44  In what context can it have a distributive mea...
# ...                  ...                                                ...
# 25613__3_144    4609.855                                   Yes, Your Honor.
# 25613__3_145    4610.805                                         Thank you.
# 25613__3_146     4611.89         Thank you, counsel. Rebuttal, Mr. Clement?
# 25613__4_001    4615.225  Thank you, Mr. Chief Justice. Just a few point...
# 25613__4_002     4802.28  Thank you, counsel, all counsel. The case is s...
#
# ...
